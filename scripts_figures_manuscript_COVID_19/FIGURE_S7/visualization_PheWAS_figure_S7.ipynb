# %%
# import libraries
from pandas import DataFrame
from scipy.stats import uniform
from scipy.stats import randint
import pandas as pd
import matplotlib.pyplot as plt                  
import numpy as np
import seaborn as sns
import itertools


# sample data
fs="\t"

path="/Users/Hp/Desktop/2000_cohort_analysis/"
 # import feature count matrix whole set


# wholeset 2000 cohort 
df=pd.read_csv(path + "PheWAS_data_general_category.csv")
df.head()
# Out:
#                                General category  asymptomatic  severe
# 0                        nervous system disease            51      57
# 1                   cell proliferation disorder            53      50
# 2  musculoskeletal or connective tissue disease            44      41
# 3                        cardiovascular disease            39      37
# 4                      gastrointestinal disease            27      28

# %%
# Stacked bar chart
plt.rc('font', size=20) 
plt.rcParams["figure.figsize"] = (16, 12)
df.set_index(['General category'], inplace=True)
df = df.iloc[::-1]
plt = df.plot.barh(stacked=True, color = ['#3B53A4', '#EE2125']);

plt.figure.savefig(path+"figure_S6_PheWAS_general_category.pdf", format="pdf", bbox_inches="tight")
