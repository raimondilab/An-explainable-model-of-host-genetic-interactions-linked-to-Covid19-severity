# %%
# import libraries
from pandas import DataFrame
from scipy.stats import uniform, randint
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# sample data
fs="\t"

path="/Users/Hp/Desktop/2000_cohort_analysis/"

# %%
# import datasets 
df1=pd.read_csv(path + "merged_general_XGB_updated.csv")
df1.set_index(['General category'], inplace=True)
plt.rcParams["figure.figsize"] = (8, 6)
df1[['asymptomatic', 'severe']].plot(kind='bar', color = ['b', 'r'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel('Counts')
plt.title('Severe and Asymptomatic cases comparisons XGBoost non-zero variants')
# Out:
# Text(0.5, 1.0, 'Severe and Asymptomatic cases comparisons XGBoost non-zero variants')

# %%
plt.rc('font', size=16) 
df1=pd.read_csv(path + "merged_pheno_specific_16_full_XGB_corrected_version_updated.csv")
df1.set_index(['Specific category'], inplace=True)
df1 = df1.iloc[::-1]
plt = df1.plot.barh(stacked=True, color = ['b', 'r']);

#plt.figure.savefig(path+"merged_pheno_specific_traits_updated.pdf", format="pdf", bbox_inches="tight")

# %%
## Pie-chart
from matplotlib import pyplot as plt
plt.rc('font', size=18)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
group = ['asymptomatic', 'severe']
value = [30,70]
ax.pie(value, colors = ['b', 'r'], labels = group,autopct='%1.1f%%')
plt.title('Respiratory or thoracic disease')
plt.savefig(path+'Respiratory_disease_pie_chart.pdf', format="pdf", bbox_inches="tight")
plt.show()
